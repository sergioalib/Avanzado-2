# %% [markdown]
# <a href="https://colab.research.google.com/github/sergioalib/Avanzado-2/blob/main/1_2_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pylab as plt
import numpy as np
from netCDF4 import Dataset

# %%
"""**Hora 19:30 UTC-13:30 Hora en Costa Rica** producto: **Radiances**

Banda 1
"""

# !wget https://noaa-goes16.s3.amazonaws.com/ABI-L1b-RadF/2020/262/19/OR_ABI-L1b-RadF-M6C01_G16_s20202621930205_e20202621939513_c20202621939571.nc

"""Banda 2"""

# !wget https://noaa-goes16.s3.amazonaws.com/ABI-L1b-RadF/2020/262/19/OR_ABI-L1b-RadF-M6C02_G16_s20202621930205_e20202621939513_c20202621939561.nc

"""Banda 13

"""

# !wget https://noaa-goes16.s3.amazonaws.com/ABI-L1b-RadF/2020/262/19/OR_ABI-L1b-RadF-M6C13_G16_s20202621930205_e20202621939524_c20202621940002.nc
# Out:
# --2021-09-23 20:56:48--  https://noaa-goes16.s3.amazonaws.com/ABI-L1b-RadF/2020/262/19/OR_ABI-L1b-RadF-M6C01_G16_s20202621930205_e20202621939513_c20202621939571.nc
# Resolving noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)... 52.217.81.52
# Connecting to noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)|52.217.81.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85813743 (82M) [binary/octet-stream]
# Saving to: ‘OR_ABI-L1b-RadF-M6C01_G16_s20202621930205_e20202621939513_c20202621939571.nc’
#
# OR_ABI-L1b-RadF-M6C 100%[===================>]  81.84M  37.2MB/s    in 2.2s
#
# 2021-09-23 20:56:51 (37.2 MB/s) - ‘OR_ABI-L1b-RadF-M6C01_G16_s20202621930205_e20202621939513_c20202621939571.nc’ saved [85813743/85813743]
#
# --2021-09-23 20:56:51--  https://noaa-goes16.s3.amazonaws.com/ABI-L1b-RadF/2020/262/19/OR_ABI-L1b-RadF-M6C02_G16_s20202621930205_e20202621939513_c20202621939561.nc
# ...

# %%
CH1= Dataset('OR_ABI-L1b-RadF-M6C01_G16_s20202621930205_e20202621939513_c20202621939571.nc')
CH2 = Dataset('OR_ABI-L1b-RadF-M6C02_G16_s20202621930205_e20202621939513_c20202621939561.nc')
CH13= Dataset('OR_ABI-L1b-RadF-M6C13_G16_s20202621930205_e20202621939524_c20202621940002.nc')

# %%
np.shape(CH1.variables['Rad'][:])
# Out:
# (10848, 10848)

# %%
np.shape(CH13.variables['Rad'][:])
# Out:
# (5424, 5424)

# %%
np.shape(CH2.variables['Rad'][:])
# Out:
# (21696, 21696)

# %%
BLUE = CH1.variables['Rad'][:][::2,::2]
GREEN =CH13.variables['Rad'][:][::1,::1]
RED=CH2.variables['Rad'][:][::4,::4]

RED=(RED-RED.min())/(RED.max()-RED.min())
GREEN=(GREEN-GREEN.min())/(GREEN.max()-GREEN.min())
BLUE=(BLUE-BLUE.min())/(BLUE.max()-BLUE.min())

# %%
COLORES=np.zeros((5424, 5424,3))

COLORES[:,:,0]=RED

COLORES[:,:,1]=GREEN

COLORES[:,:,2]=BLUE

plt.figure(figsize = (5,5),dpi=150)
plt.title('RGB con canales 1-2-13 a las 19:30 UTC con el producto "raciances"')
plt.bar
plt.imshow(COLORES)

plt.figure(figsize = (5,5),dpi=150)
plt.xlim(2000,2500)
plt.ylim(2300,2000)
plt.title('RGB con canales 1-2-13 a las 19:30 UTC con el producto "raciances"')
plt.imshow(COLORES)

plt.figure(figsize = (5,5),dpi=150)
plt.xlim(2200,2300)
plt.ylim(2300,2200)
plt.title('RGB con canales 1-2-13 a las 19:30 UTC con el producto "raciances"')
plt.imshow(COLORES)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
